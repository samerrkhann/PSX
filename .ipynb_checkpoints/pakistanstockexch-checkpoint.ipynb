# %% [markdown]
# # Roll NO  : Name
# # CS-172061 : Moiz Ullah Khan
# # CS172029 : Muhammad Qasim
# # CS172041 : Haider Naseer

# %% [markdown]
# # Stock Market Prediction

# %% [markdown]
# 1. Exploratory Data Analysis
#     * Correlation
#     * Removing outliers from dataset
#     * Visualization of Data
#         * Why Stock market crash in 2009
#
#
#
# 2. Long-Short Term Model LSTM for prediction
#     * Spliting the Dataset
#     * Using Min Max Scaler for scaling data
#     * LSTM
#     * Prediction

# %%
#importing the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#for LSTM layers of neurons
import tensorflow as tf

# %%
st_df = pd.read_csv('/kaggle/input/pakistan-stock-exchange-kse-100/Stock Exchange KSE 100(Pakistan).csv')

# %%
st_df.shape
# Out:
# (3221, 7)

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3221 non-null   object
#  1   Open    3221 non-null   object
#  2   High    3221 non-null   object
#  3   Low     3221 non-null   object
#  4   Close   3221 non-null   object
#  5   Change  3221 non-null   object
#  6   Volume  3221 non-null   object
# dtypes: object(7)
# memory usage: 176.3+ KB

# %%
#resetting the index
st_df['Date'] = pd.to_datetime(st_df['Date'])
st_df.set_index('Date',inplace=True)

# %%
#remove the comma in prices
st_df = st_df.replace(regex=[','], value='')

# %%
#change the datatype of columns
st_df['Open'] = pd.to_numeric(st_df['Open'], errors='coerce')
st_df['Close'] = pd.to_numeric(st_df['Close'], errors='coerce')
st_df['High'] = pd.to_numeric(st_df['High'], errors='coerce')
st_df['Low'] = pd.to_numeric(st_df['Low'], errors='coerce')
st_df['Change'] = pd.to_numeric(st_df['Change'], errors='coerce')
st_df['Volume'] = pd.to_numeric(st_df['Volume'], errors='coerce')

# %%
st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3221 entries, 2021-02-23 to 2008-02-22
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3221 non-null   float64
#  1   High    3221 non-null   float64
#  2   Low     3221 non-null   float64
#  3   Close   3221 non-null   float64
#  4   Change  3221 non-null   float64
#  5   Volume  3221 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 176.1 KB

# %%
st_df.head()
# Out:
#                 Open      High       Low     Close  Change     Volume
# Date
# 2021-02-23  31722.16  31800.90  31597.31  31626.19  -21.38  718191025
# 2021-02-22  31874.78  31958.58  31612.55  31647.57 -203.61  721952658
# 2021-02-19  31748.75  31904.30  31749.43  31851.18   91.36  694795084
# 2021-02-18  32049.85  32104.67  31745.72  31759.82 -288.86  577837595
# 2021-02-17  32166.21  32390.77  32044.01  32048.68  -93.15  701658181

# %%
st_df.describe()
# Out:
#                Open          High           Low         Close       Change  \
# count   3221.000000   3221.000000   3221.000000   3221.000000  3221.000000
# mean   18806.389208  18913.961723  18694.557457  18801.652980     6.662738
# std     9556.736989   9599.905455   9502.488358   9550.963841   288.333717
# min     3634.560000   3742.310000   3623.350000   3647.100000 -8060.960000
# 25%     8418.150000   8479.860000   8348.880000   8426.350000   -68.460000
# 50%    21777.350000  21885.330000  21640.080000  21771.630000     6.330000
# 75%    27911.000000  28108.020000  27656.070000  27895.150000    95.560000
# max    36317.920000  36389.500000  36132.760000  36234.200000  7957.090000
#
#              Volume
# count  3.221000e+03
# mean   2.006365e+08
# std    1.348805e+08
# min   -1.525267e+08
# 25%    1.120844e+08
# 50%    1.702730e+08
# 75%    2.543143e+08
# max    1.124724e+09

# %% [markdown]
# The difference b/w 75% percentile and max value is not high its mean there is less number of outliers in our dataset

# %%
#checking null values
st_df.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Change    0
# Volume    0
# dtype: int64

# %%
#checking not a number nan value
st_df.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Change    0
# Volume    0
# dtype: int64

# %%
#dropping the duplicates
st_df.drop_duplicates(keep=False, inplace=True)

# %%
st_df.shape
# Out:
# (3221, 6)

# %% [markdown]
# ## Exploraotry Data Analysis - EDA

# %%
#correlation b/w columns/ variables
correlation = st_df.corr()

# %%
#finding the correlation b/w variables
sns.heatmap(correlation, xticklabels=correlation.columns, 
            yticklabels=correlation.columns, 
            annot=True)
# Out:
# <AxesSubplot:>

# %%
#finding the outliers in dataset
st_df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Handling outliers

# %%
#taking the Quantile (q1) and q3 and then subtract it for to find inter quantile range
Q1 = st_df.quantile(0.25)
Q3 = st_df.quantile(0.75)

IQR = Q3-Q1
print(IQR)
# Out:
# Open      1.949285e+04
# High      1.962816e+04
# Low       1.930719e+04
# Close     1.946880e+04
# Change    1.640200e+02
# Volume    1.422299e+08
# dtype: float64

# %%
st_df = st_df[~((st_df < (Q1 -1.5 * IQR)) | (st_df > (Q3 + 1.5 *IQR))).any(axis=1)]

# %%
st_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
#viualize the variables
sns.pairplot(st_df)

# %%
#visualize the volume of stock price
st_df['Volume'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
np.log(st_df['Volume']).plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#visualize the volume quarterly
st_df['Volume'].resample('Q').mean().plot(figsize=(20,10), kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#visualize change in stocks
st_df['Change'].resample('Q').mean().plot(figsize=(20,10), kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
closing = st_df[['Close']]
st_df.rolling(12).mean().plot(figsize=(20,10), color=['yellow','red', 'green', 'blue','brown','orange'],linewidth=5, fontsize=20)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#visualize open and close of market by taking mean
Open_close = pd.concat([st_df[['Open']].rolling(12).mean(), st_df[['Close']].rolling(12).mean()], axis=1)
Open_close .plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# * In the start of 2008 Pakistan stock market is going to crash

# %% [markdown]
# ### Stock Market Crashing

# %%
# #searching for the market crash in 2008
# from googlesearch import search
# query = 'Pakistan stock market crash 2008'
  
# print('Links for market crash:')
# for j in search(query, num=5, stop=5):
#     print(j)

# %%
#visualize the high and low price
high_close = pd.concat([st_df[['High']].rolling(12).mean(), st_df[['Low']].rolling(12).mean()], axis=1)
high_close.plot(figsize=(20,10), linewidth=5, fontsize=15)
plt.xlabel('Year', fontsize=15)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ## Long Short Term Model - LSTM

# %%
#importing the libraries for LSTM
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import *

#scaling the input and output
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
#splitting the dataset in train and test
train_set = st_df.iloc[:800, 1:2].values
test_set = st_df.iloc[800:,1:2].values

print(train_set.shape)
print(test_set.shape)
# Out:
# (800, 1)
# (2007, 1)

# %%
# train_set,test_set

# %%
#scaling the train and test data
# st_df = st_df.reset_index()
scale = MinMaxScaler(feature_range = (0,1))
train_set_scaling = scale.fit_transform(train_set)

train_X = []
train_y = []

for i in range(60, len(train_set_scaling)):
    train_X.append(train_set_scaling[i-60:i, 0])
    train_y.append(train_set_scaling[i, 0])
    
train_X, train_y = np.array(train_X), np.array(train_y)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1],1))

# %%
model = Sequential()

#adding the input layer
model.add(LSTM(30, return_sequences=True, input_shape=(train_X.shape[1],1)))
model.add(Dropout(0.3))

#Dense layers
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(50))
model.add(Dropout(0.3))

model.add(Dense(30,activation='relu'))

#ouput layer
model.add(Dense(1, activation='softmax'))

#calculating loss
model.compile(loss='mean_squared_error', optimizer='adam')

# fit network
model.fit(train_X, train_y, epochs=100, batch_size=25)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 11s 138ms/step - loss: 0.2520
# Epoch 2/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2330
# Epoch 3/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2357
# Epoch 4/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.2389
# Epoch 5/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2443
# Epoch 6/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2437
# Epoch 7/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2450
# Epoch 8/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2374
# Epoch 9/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2508
# Epoch 10/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2476
# Epoch 11/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2530
# Epoch 12/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.2509
# Epoch 13/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2286
# Epoch 14/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2396
# Epoch 15/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2490
# Epoch 16/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2472
# Epoch 17/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2507
# Epoch 18/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2458
# Epoch 19/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2450
# Epoch 20/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.2519
# Epoch 21/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.2354
# Epoch 22/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2516
# Epoch 23/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2385
# Epoch 24/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2351
# Epoch 25/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2534
# Epoch 26/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.2466
# Epoch 27/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2496
# Epoch 28/100
# 30/30 [==============================] - 4s 147ms/step - loss: 0.2475
# Epoch 29/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2448
# Epoch 30/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2483
# Epoch 31/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.2408
# Epoch 32/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2419
# Epoch 33/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.2383
# Epoch 34/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2377
# Epoch 35/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2493
# Epoch 36/100
# 30/30 [==============================] - 4s 148ms/step - loss: 0.2332
# Epoch 37/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2464
# Epoch 38/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2498
# Epoch 39/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2465
# Epoch 40/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2416
# Epoch 41/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.2502
# Epoch 42/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2595
# Epoch 43/100
# 30/30 [==============================] - 4s 141ms/step - loss: 0.2380
# Epoch 44/100
# 30/30 [==============================] - 4s 150ms/step - loss: 0.2511
# Epoch 45/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2477
# Epoch 46/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2463
# Epoch 47/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2518
# Epoch 48/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2367
# Epoch 49/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2435
# Epoch 50/100
# 30/30 [==============================] - 4s 141ms/step - loss: 0.2613
# Epoch 51/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2390
# Epoch 52/100
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2483
# Epoch 53/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2568
# Epoch 54/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2441
# Epoch 55/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2405
# Epoch 56/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2463
# Epoch 57/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2394
# Epoch 58/100
# 30/30 [==============================] - 4s 141ms/step - loss: 0.2415
# Epoch 59/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2435
# Epoch 60/100
# 30/30 [==============================] - 4s 142ms/step - loss: 0.2525
# Epoch 61/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2463
# Epoch 62/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2579
# Epoch 63/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2563
# Epoch 64/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2405
# Epoch 65/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2323
# Epoch 66/100
# 30/30 [==============================] - 4s 142ms/step - loss: 0.2551
# Epoch 67/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2454
# Epoch 68/100
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2412
# Epoch 69/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2390
# Epoch 70/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2388
# Epoch 71/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2450
# Epoch 72/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2429
# Epoch 73/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2403
# Epoch 74/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2359
# Epoch 75/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2566
# Epoch 76/100
# 30/30 [==============================] - 4s 142ms/step - loss: 0.2533
# Epoch 77/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2461
# Epoch 78/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.2460
# Epoch 79/100
# 30/30 [==============================] - 4s 138ms/step - loss: 0.2481
# Epoch 80/100
# 30/30 [==============================] - 4s 136ms/step - loss: 0.2485
# Epoch 81/100
# 30/30 [==============================] - 4s 140ms/step - loss: 0.2421
# Epoch 82/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2404
# Epoch 83/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.2425
# Epoch 84/100
# 30/30 [==============================] - 4s 137ms/step - loss: 0.2498
# Epoch 85/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2276
# Epoch 86/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2376
# Epoch 87/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2457
# Epoch 88/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2533
# Epoch 89/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.2508
# Epoch 90/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2403
# Epoch 91/100
# 30/30 [==============================] - 4s 133ms/step - loss: 0.2472
# Epoch 92/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2434
# Epoch 93/100
# 30/30 [==============================] - 4s 139ms/step - loss: 0.2364
# Epoch 94/100
# 30/30 [==============================] - 4s 131ms/step - loss: 0.2543
# Epoch 95/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2459
# Epoch 96/100
# 30/30 [==============================] - 4s 135ms/step - loss: 0.2478
# Epoch 97/100
# 30/30 [==============================] - 4s 143ms/step - loss: 0.2467
# Epoch 98/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2480
# Epoch 99/100
# 30/30 [==============================] - 4s 134ms/step - loss: 0.2486
# Epoch 100/100
# 30/30 [==============================] - 4s 132ms/step - loss: 0.2439

# %%
#setting the test data
train_data = st_df.iloc[:800 ,1:2]
test_data = st_df.iloc[800: ,1:2]

df = pd.concat((train_data, test_data), axis=0)

inputs = df[len(df)-len(test_data)-60:].values

inputs = inputs.reshape(-1, 1)
inputs = scale.transform(inputs)
test_X = []

for i in range(60, 519):
    test_X.append(inputs[i-50:i, 0])
    
test_X = np.array(test_X)
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))
print(test_X.shape)
# Out:
# (459, 50, 1)

# %%
train_X.shape
# Out:
# (740, 60, 1)

# %%
#preding the closing price of stock
pred_stk_price = model.predict(test_X)
pred_stk_price = scale.inverse_transform(pred_stk_price)

# %%
plt.figure(figsize=(20,10))
plt.plot(test_data,'red',label='Closing Prices')
plt.plot(pred_stk_price,'blue',label='Predicted closing Prices')
plt.xlabel('Date',size=20)
plt.xticks(size=20)
plt.ylabel('Prices',size=20)
plt.yticks(size=20)
plt.title('Real vs Predicted closing Prices')
plt.legend(loc='best', fontsize=20)
